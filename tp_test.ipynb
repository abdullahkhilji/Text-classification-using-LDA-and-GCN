# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import spacy

print('Input DataSet Name')
dataset = input()
dataset_path = 'pre_processed_dataframe_all/' + 'pre_processed_' + dataset + '.csv'

# spacy for lemmatization


# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
# Out:
# Input DataSet Name
# mr

# %%
df = pd.read_csv(dataset_path)
orig_df = df
df.rename(columns={'0': "content", '1': "labels"}, inplace=True)
data = df.content.values.tolist()
data_list = list(data)

# %%
data_list[-1]
# Out:
# nan

# %%
data_words = [i.split() for i in data_list]

print(data_words[:1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-85ad4e69b7af> in <module>
# ----> 1 data_words = [i.split() for i in data_list]
#       2
#       3 print(data_words[:1])
#
# <ipython-input-9-85ad4e69b7af> in <listcomp>(.0)
# ----> 1 data_words = [i.split() for i in data_list]
#       2
#       3 print(data_words[:1])
#
# AttributeError: 'float' object has no attribute 'split'

# %%
data_words
# Out:
# ['moore like progressive bull china shop provocateur crashing ideas special interest groups slaps together brand liberalism',
#  'idiotic ugly',
#  'even naipaul original remains real masterpiece movie possesses languorous charm',
#  'movie amateurish minor treat',
#  'people march beat different drum ever wondered kind houses people live documentary takes look alternative housing options',
#  'movie plays cartoon obvious strength snazziness neglecting less conspicuous writing strength',
#  'apesar de seus graves problemas filme consegue entreter',
#  'superb production values christian bale charisma make derivative plot',
#  'kiarostami crafted deceptively casual ode children managed convey tiny sense hope',
#  'engrossing story combines psychological drama sociological reflection high octane thriller',
#  'like predecessor classic provides reasonably attractive holiday contraption one families looking clean kid friendly outing investigate',
#  'ranks among willams best screen work',
#  'drawling slobbering lovable run sentence film southern gothic emotional arc raw blues soundtrack',
#  'even understand earth going movie stimulate hours post viewing discussion reminded',
#  'sight spaceship launching pad duly impressive imax dimensions shots astronauts floating cabins',
#  'new zealand coming age movie really anything rich luscious cares',
#  'french cast marveilleux',
#  'ricci best work yet girl woman sincerely believes thwart world misery blind good',
#  'harmless fun',
#  'fast runner transports viewer unusual space',
#  'may somewhat backhanded compliment say film makes viewer feel like movie various victimized audience members also happens movie admirable quality',
#  'funny movie',
#  'imagine scenario bergman approaches swedish fatalism using gary larson far side humor',
#  'minutes treasure planet maintains brisk pace races familiar story however lacks grandeur epic quality often associated stevenson tale well earlier disney efforts',
#  'lot fun undeniable energy sparked two actresses working peak powers',
#  'vivid sometimes surreal glimpse mysteries human behavior',
#  'film verbal duel two gifted performers',
#  'valuable film',
#  'director kapur filmmaker real flair epic landscapes adventure better film earlier english language movie overpraised elizabeth',
#  'love way took chances really asks take great leaps faith pays',
#  'take care nicely performed quintet actresses nonetheless drags minute length',
#  'expect major discoveries stylish sizzle film sits square conviction touching good sense experience women',
#  'transitions adulthood fraught much truth small amount poetry girls swim',
#  'funny sexy devastating incurably romantic',
#  'death merely transition common tenet world religions deeply spiritual film taps meaning consolation afterlife communications',
#  'highly personal look effects living dysfunctionally privileged lifestyle end wish could spent time world',
#  'absorbing character study andr turpin',
#  'skins desolate air eyre native american raised white parents manages infuse rocky path sibling reconciliation flashes warmth gentle humor',
#  'world traveler might go anywhere new arrive anyplace special certainly honest attempt get something',
#  'pleasing often funny comedy',
#  'enlivens film beyond astute direction cardoso beautifully detailed performances actors note defiance social dictates',
#  'fascinating bombshell documentary shame americans regardless whether ultimate blame finally lies kissinger required viewing civics classes would public servants alike',
#  'like going house party watching host defend frothing ex girlfriend want call cops want call domino',
#  'contrasting original ringu current americanized adaptation akin comparing evil dead evil dead ii',
#  'fans critics darling band wilco marvel sometimes murky always brooding look trying break heart',
#  'film precious increments artfully camouflaged everyday activities',
#  'greene delivers typically solid performance role bit departure noble characters played past matched schweig carries film broad handsome shoulders',
#  'film fierce dance destruction flame like roiling black white inspires trembling gratitude',
#  'wonderful ghastly film',
#  'stanley kwan directed one best gay love stories ever made one best love stories stripe',
#  'people cinema finest',
#  'one funniest motion pictures year also one curiously depressing',
#  'steven soderbergh digital video experiment clever cutting quick dirty look modern living movie life',
#  'suffers timid parsing barn side target sons trying breach gaps relationships fathers',
#  'moving important film',
#  'friends couples miles pabst blue ribbon beer drink ultimate redneck road trip',
#  'comedy subversive unrelenting bleak insistence opting opportunity finding meaning relationships work becomes sad',
#  'two words tell know deciding see anthony hopkins',
#  'coming age story seen bits films rarely told affecting grace cultural specificity',
#  'claire terrific role someone like judd really ought playing villains',
#  'intrigued politics film every bit fascinating flawed',
#  'taking entertainment tonight subject matter giving humor poignancy auto focus becomes gut bustingly funny crushingly depressing',
#  'clever script skilled actors bring new energy familiar topic office politics',
#  'cast phenomenal especially women',
#  'nettelbeck crafted engaging fantasy flavours emotions one part romance novel one part recipe book',
#  'admired particularly unexpected downer ending',
#  'film almost unbearable portrait sadness grief transcends specific story speak ways need history presumption tangle sometimes destroy blood ties',
#  'payne constructs hilarious ode middle america middle age unlikely odyssey featuring pathetic endearing hero human',
#  'first half bursts goofy energy previous disney films used minutes',
#  'schmidt nicholson goofy heartfelt mesmerizing king lear',
#  'smart provocative drama nearly impossible gets skin man know evil monstrous lunatic',
#  'see debate remember',
#  'tough watch fantastic movie',
#  'exciting documentary',
#  'cut layers soap opera emotion find scathing portrayal powerful entity strangling life people want believe',
#  'highly engaging',
#  'succeeds bullock grant made share silver screen',
#  'mazel tov film family joyous life acting yiddish stage',
#  'characters well established gang feels comfortable taking insane liberties goofiest stuff left field',
#  'celebrates group playful spark nonconformity glancing vividly back hibiscus grandly called angels light',
#  'strange beautiful film',
#  'makes aborbing arguable case man greatness',
#  'though intrepid exploring attraction crosses sexual identity ozpetek falls short showing us antonia true emotions least secret life leave thinking',
#  'amazing film work convincing movies end swear wet places feel sand creeping others',
#  'great deal sizzle little steak spectacular sizzle incarnation fizz infectious',
#  'indispensable peek art agony making people laugh',
#  'evokes little fear parents possible futures children sometimes bad choices mothers fathers make interests good',
#  'stylistic romp always fun watch',
#  'different others genre rely dumb gags anatomical humor character cliches primarily relies character tell story',
#  'britney delivered big screen safe sound way like year old superstar girls travel fame freeway',
#  'culture clash comedy addition funny captures discomfort embarrassment bumbling american europe',
#  'old fashioned drama substance teacher slide slippery slope dishonesty encounter rich powerful nothing disdain virtue',
#  'visually seductive unrepentantly trashy take rice second installment vampire chronicles',
#  'argento brings youthful change world aggressiveness project cut open vein bled raw film stock',
#  'graced kind social texture realism would foreign american teen comedies',
#  'makes esther kahn demanding progresses low key manner risks monotony worth concentration',
#  'anyone ever fantasized space travel afford million ticket ride russian rocket catch imax offering',
#  'thoroughly enjoyable',
#  'terrific b movie fact best recent memory',
#  'times funny times candidly revealing intriguing look two performers put love',
#  'film class spike lee masterful right thing',
#  'building slowly subtly film sporting breezy spontaneity realistically drawn characterizations develops significant character study moving wise',
#  'watch sense openness little surprises',
#  'gulpilil commanding screen presence character abundant humanism makes film moral compass',
#  'enjoyable feel good family comedy regardless race',
#  'great monster movie paid matinee price bought big tub popcorn guilty fun chomp chomp',
#  'film advertised comedy sweet home alabama funny hoped film advertised comedy sweet home alabama funny hoped',
#  'heaven haunting dramatization couple moral ascension',
#  'object idea vietnam picture rah rah patriotic tone soldiers ultimately achieves main strategic objective dramatizing human cost conflict came define generation',
#  'looking intelligent movie release pent anger enough ticket need',
#  'wife actress utterly charming french comedy feels american sensibility style virtually hollywood remake',
#  'image',
#  'honestly address flaws inherent medical aid made available american workers balanced fair portrayal sides needed',
#  'ingenious often harrowing look damaged people families offer either despair consolation',
#  'best film year far benchmark best picture contenders measured',
#  'film rival live fine little amuse bouche keep appetite whetted',
#  'diverting enough hour half family audience',
#  'big trouble could considered funny little film',
#  'reason miss interview assassin',
#  'surest bet around good time movies summer',
#  'perhaps cliche call film refreshing drumline shows level young black manhood funny touching smart complicated',
#  'totally weirded notion cinema community therapy spectacle quitting hits home disorienting force',
#  'jeffrey tambor performance intelligent jazz playing exterminator oscar worthy',
#  'despite old hat set predictable plot empire still enough moments keep entertaining',
#  'anything else kissing jessica stein injects freshness spirit romantic comedy genre held hostage generic scripts seek remake sleepless seattle',
#  'pray film works well appeal even familiar turntablism',
#  'jones tackled meaty subject drawn engaging characters peppering pages memorable zingers',
#  'stirring road movie',
#  'suspend disbelief shaking head way credits',
#  'effective tepid biopic',
#  'works pretty contagious fun',
#  'want funk movie got',
#  'film darkly funny observation much grueling time consuming illusion work actual work',
#  'one funnier movies town',
#  'immediacy intimacy sucks dares believe true',
#  'fans modern day hong kong action film finally worthy successor better tomorrow killer patiently waiting',
#  'good film falls short aspiration true epic',
#  'rawness vitality give considerable punch',
#  'take year old boy see picture slave year',
#  'rather brilliant little cult item pastiche children entertainment superhero comics japanese animation',
#  'exuberantly romantic serenely melancholy time may prove tsai masterpiece',
#  'good piece work often',
#  'compelling story musical passion governmental odds',
#  'invigorating surreal resonant rainbow emotion',
#  'resonant tale racism revenge retribution',
#  'frei assembles fascinating profile deeply humanistic artist spite witnessed remains surprisingly idealistic retains extraordinary faith ability images communicate truth world around',
#  'mr polanski element alone abandoned still consoled art ever revealed source spiritual survival',
#  'nearly three hours whole safe conduct less sum parts',
#  'rare documentary incorporates much human experience drama conflict tears surprise transcends normal divisions fiction nonfiction film',
#  'haynes fanatically fetishized every bizarre old movie idiosyncrasy monastic devotion sure applaud look committed',
#  'film grows',
#  'makes movie work admittedly limited extent commitment two genuinely engaging performers weaver lapaglia excellent kind low key way allows us forget actually movie folk',
#  'goofy nutty consistently funny educational',
#  'subtle humorous illuminating study politics power social mobility',
#  'steers feature film debut created brilliant motion picture',
#  'wickedly funny visually engrossing never boring movie challenges us think ways consume pop culture',
#  'plethora engaging diatribes meaning home delivered grand passion members various households',
#  'altogether successful film time touching reconsideration familiar masterpiece',
#  'impresses open endedness surprises',
#  'although occasionally static point resembling stage play film delivers solid mixture sweetness laughs',
#  'full bland hotels highways parking lots glimpses nature family warmth time discreet moan despair entrapment maze modern life',
#  'compelling mix trial movie escape movie unexpected fable ensures film never feels draggy',
#  'paradiso rusted ruin ultimate collapse film final restored third emotionally belittle cinema classic sometimes shorter better',
#  'captivating coming age story may also first narrative film truly informed wireless age',
#  'script snazzy dialogue establishes realistic atmosphere involves us unfolding crisis lazy plotting ensures little emotional investment pays',
#  'second chapter harry potter series even magical first simply best family film year',
#  'lohman film performance moves heartbreak rebellion continually tries accommodate fit gain unconditional love seeks',
#  'anchored terrific performance abbass satin rouge shows idea women self actualization knows continental divides',
#  'scherfig made movie leave wondering characters lives clever credits roll',
#  'stylishly directed verve',
#  'great fun sports aficionados ordinary louts whose idea exercise climbing steps stadium seat megaplex',
#  'whole mildly pleasant outing r rating brief nudity grisly corpse remains aloft self referential hot air inspired performance tim allen',
#  'crush clever captivating romantic comedy welcome pinch tartness',
#  'several degrees shy gross contests one expects current teen fare',
#  'know precisely make steven soderbergh full frontal though stop enjoying much',
#  'certainly performances worthwhile',
#  'disreputable air whole thing makes irresistible',
#  'wonder hope magic never escape heart boy right movie comes along especially begins name star wars',
#  'buy accomplished actress big juicy role',
#  'one strictly lightweight escapist film',
#  'something ultimate scorsese film stomach turning violence colorful new york gang lore hallmarks personal cinema painted largest ever historical canvas',
#  'movie trove delights',
#  'elegant exquisitely modulated psychological thriller',
#  'emerge clearer view gears justice grind death report comes share airtime alongside farm report',
#  'dark water complete wash pun intended watched side side ringu ultimately comes pale successor',
#  'intimate panoramic',
#  'exquisitely crafted acted tale',
#  'still pretentious filled subtext entertaining enough face value recommend anyone looking something different',
#  'amusing breezily apolitical documentary life campaign trail',
#  'capable nailbiter',
#  'one war movies focuses human interaction rather battle action sequences stronger',
#  'stevens flair dialogue comedy film operates nicely element surprise large cast solid',
#  'maggie smith ya ya member tank absolutely crack crass gasp gas verbal deportment',
#  'entirely suspenseful extremely well paced ultimately dare say entertaining',
#  'see wheels turning might resent sometimes still nice little picture made bright friendly souls lot good cheer',
#  'foster breathes life roll could otherwise bland run mill',
#  'serviceable euro trash action extravaganza decent sense humor plenty things go boom handguns bmws seaside chateaus',
#  'possession based book byatt demands labute deal subject love head trading cynicism reverence little wit',
#  'watching two actors play intensely restraint treat',
#  'accident accidental spy solid action pic returns martial arts master top form',
#  'masterpiece four years making',
#  'reno left liberal political spectrum tough funny rather chaotic show subversive much nit picky hypocrisies time',
#  'angel presents events partly perspective aurelie christelle infuses film sensibility particularly nightmarish fairytale',
#  'intelligent multi layered profoundly humanist mention gently political meditation values knowledge education affects cultural geographical displacement',
#  'slick skillful little horror film',
#  'plot follows predictable connect dots course director john schultz colors picture evocative shades',
#  'individual moments mood aimlessness actually sort amazing',
#  'witty whimsical feature debut',
#  'extraordinary swedish film soul adventure marriage kind intimate character driven film bille august best',
#  'word comes mind watching eric rohmer tribute courageous scottish lady painterly',
#  'stories potential touched angel simplicity sappiness thirteen conversations one thing generosity optimism never resorts easy feel good sentiments',
#  'fast frantic fun also soon forgotten',
#  'much movie picture book big screen favorite series still enjoyed enough recommend',
#  'audiences advised sit near back squint avoid noticing truly egregious lip non synching otherwise production suitably elegant',
#  'could first major studio production shot video tape instead film',
#  'distance picture provides satisfyingly unsettling ride dark places national psyche',
#  'bloody sunday grace call prevention rather place blame making one best war movies ever made movie accomplishes much one viewing possibly enough',
#  'lovely amazing holofcener deep uncompromising curtsy women knows likely said done loves pieces trust',
#  'though overall overwhelmingly positive portrayal film ignore problematic aspects brown life',
#  'watstein handily directs edits around screenplay sappier elements sustains hook buildup remarkable assuredness first timer',
#  'testament de niro director michael caton jones movie end accept characters film flaws',
#  'evokes th century subtlety object lesson period filmmaking',
#  'una pel cula oscura precisa por momentos grandiosa casi siempre conmovedora',
#  'great summer fun watch arnold buddy gerald bounce quirky cast characters',
#  'leigh one rare directors feels acting heart soul cinema allows cast members make creative contributions story dialogue method almost never fails works superbly',
#  'reminder beyond hype recent digital glitz spielberg knows tell us people',
#  'manages transcend sex drugs show tunes plot something far richer',
#  'principals cast fine bishop stevenson standouts',
#  'average coming age tale elevated wholesome twist pesky mother interfering son discovery homosexuality',
#  'scope ambition accomplishment children century takes kurys career whole new level',
#  'moments account life artist frida kahlo among cinema finest year unfortunately sandwiched impossibly dry account kahlo life imaginable',
#  'one smarter offerings horror genre produced recent memory even far tamer advertised',
#  'wife actress works well leads companionable couple',
#  'myers turned franchise movie version adolescent dirty joke book done post tarantino pop culture riffs',
#  'way roundelay partners functions interplay within partnerships among partnerships general air gator bashing consistently delightful',
#  'walk good girl mixed emotions disapproval justine combined tinge understanding actions',
#  'lohman adapts changes required actress director peter kosminsky never get audience break wall character erects',
#  'delightful entree tradition food movies',
#  'turntable outselling electric guitar',
#  'skin man gets cheap shocks kids peril theatrics also taps primal fears young people trying cope mysterious brutal nature adults',
#  'good hard edged stuff violent bit exploitative also nicely done morally alert street smart',
#  'though particular interest students enthusiast international dance world music film designed make viewers ages cultural backgrounds rhythmic ability want get dance',
#  'danny huston gives astounding performance deftly gradually reveals real human soul buried beneath spellbinding serpent smirk',
#  'harsh effective documentary life israeli occupied palestinian territories',
#  'case convincing one give anyone conscience reason pause',
#  'extends writings jean genet john rechy films fassbinder perhaps even nocturnal works goya',
#  'dogtown z boys evokes blithe rebel fantasy kind insouciance embedded sexy demise james dean',
#  'drama cube personal revelations regarding shop means big picture iconic characters gambol fluidly story charming results',
#  'entire cast extraordinarily good',
#  'take grandkids grandparents never worry anyone bored audience sea constant smiles frequent laughter',
#  'impossible romance root patronized iranian lad',
#  'sharp amusing study cult celebrity',
#  'surface silly comedy scotland pa would forgettable clever adaptation bard tragic play',
#  'film different apple striking encourage us see samira makhmalbaf distinctive sensibility working develop film language conspicuous success',
#  'journey spanning nearly three decades bittersweet camaraderie history feel truly know makes holly marina tick hearts go continue negotiate imperfect love hate relationship',
#  'shamelessly resorting pee related sight gags might even cause tom green grimace still myer energy silliness eventually prevail',
#  'movie refreshes mind spirit along body original content look style',
#  'go see enjoy',
#  'director david jacobson gives dahmer consideration murderer never game victims',
#  'inspires continuing deeply satisfying awareness best movies monumental picture shows',
#  'wwii drama well plotted visually striking filled enjoyably complex characters never first appear',
#  'stripped dramatic constructs austere imagery abstract characters equal parts poetry politics obvious times evocative heartfelt',
#  'draw big bad love solid performance arliss howard',
#  'pianist polanski best film',
#  'stoically delivered hokum hart war never fun still worthy addition growing canon post saving private ryan tributes greatest generation',
#  'strikes hardest reminds pertinent dynamics remain fifty years fact world political situation seems little different director phillip noyce brings allegory remarkable skill',
#  'funny romantic comedy two skittish new york middle agers stumble relationship struggle furiously fears foibles',
#  'lesson prehistoric hilarity',
#  'broomfield turns distinctive blundering style something could really help clear case',
#  'passionate irrational long suffering cruel tarantula helga figures prominently movie helps keep proceedings funny grown ups rugrats',
#  'mel gibson fights good fight vietnam director randall wallace flag waving war flick core decency',
#  'tremendous piece work',
#  'overall wacky inspired little film works effortlessly delivering genuine acerbic laughs',
#  'call wimp cried three times animated sweet film',
#  'slow ponderous rohmer drama builds intense indoor drama compassion sacrifice christian love face political corruption',
#  'straightforward old fashioned best possible senses words possession movie puts squarely service lovers inhabit',
#  'things made original men black pleasure still',
#  'intimate spectacular e carried less wow factors funny moving yarn holds well two decades',
#  'singular character study perfect also year sweetest movie',
#  'martin barbara complex characters sometimes tender sometimes angry delicate performances sven wollter viveka seldahl make hopes frustrations vivid',
#  'leave rohmer find way bend current technique service vision past faithful architectural glories commanding open spaces city two centuries ago',
#  'sensitive cultivated treatment greene work well remarkably faithful one',
#  'charles entertaining film chronicles seinfeld return stand comedy wrap legendary sitcom alongside wannabe comic adams attempts get shot big time',
#  'disarmingly straightforward strikingly devious',
#  'woody allen latest ambling broad comedy love hate movie biz',
#  'senses dulled slasher films gorefests connoisseur psychological horror ticket',
#  'buy popcorn take nothing seriously enjoy ride',
#  'smart witty follow',
#  'prove female director make movie soft edges kathryn bigelow offers sugar coating interludes lightness film unrelentingly claustrophobic unpleasant',
#  'film minute running time stops shy overkill though viewers may exhausted athletes onscreen',
#  'combine paranoid claustrophobia submarine movie unsettling spookiness supernatural hollywood think sooner',
#  'family fare',
#  'adaptation simply brilliant',
#  'film quite maintain initial momentum remains sporadically funny throughout',
#  'boy vividly recalls cary grant room one houseboat father goose affectionate depiction gentle war reluctant irresponsible man kid latches onto',
#  'assayas ambitious sometimes beautiful adaptation jacques chardonne novel',
#  'story inspiring ironic revelatory ridiculous money oriented record industry really also testament integrity vision band',
#  'neither funniest film eddie murphy robert de niro ever made showtime nevertheless efficiently amusing good collapses exactly kind buddy cop comedy set lampoon anyway',
#  'pay nine bucks hear suffering afghan refugees news still unaffected dramas like make human',
#  'never know changing lanes going take heck ride samuel l jackson one best actors',
#  'good car chases great fight scenes distinctive blend european american asian influences',
#  'inhospitability land emphasizes spare precision narratives helps give atavistic power tales handed since beginning time',
#  'quite shrek monsters inc bad worth taking kids',
#  'shanghai ghetto much stranger fiction brings unknown slice history affectingly life',
#  'may particularly innovative film crisp unaffected style air gentle longing make unexpectedly rewarding',
#  'kinnear performance career defining revelation',
#  'despite flaws secretary stays head makes question firmly held positions',
#  'get root psychology film would require many sessions couch dr freud',
#  'jose campanella delivers loosely autobiographical story brushed sentimentality brimming gentle humor bittersweet pathos lyric moments linger like snapshots memory',
#  'creaky staircase gothic',
#  'though story surface deep visuals enveloping sounds blue crush make surprisingly decent flick worth summertime look see',
#  'like rocky bullwinkle speed neither completely enlightening catch intensity movie strangeness',
#  'maybe formula filmmaking nothing wrong film well crafted one',
#  'broomfield energized volletta wallace maternal fury fearlessness film crackles',
#  'film determined treat characters weak strong fallible human beings caricatures carefully delineate cost inevitable conflicts human urges institution concerned self preservation',
#  'reno delivers monologue manages incorporate horror absurdity situation well balanced fashion',
#  'refreshing see girl power movie feel prove anything',
#  'splendid entertainment young spirit accomplished aspects fullness spirit sense ease comes experience',
#  'addition hoffman powerful acting clinic rare drama offers thoughtful rewarding glimpse sort heartache everyone felt feel someday',
#  'even pushes agenda forcefully remains film something one attempts often achieves level connection concern',
#  'fresnadillo something serious say ways extravagant chance distort perspective throw us path good sense',
#  'one finest humane important holocaust movies ever made',
#  'distinguished thoughtful film marked acute writing host splendid performances',
#  'godard never made sheerly beautiful film unexpectedly moving meditation love history memory resistance artistic transcendence',
#  'splendidly illustrates ability human spirit overcome adversity',
#  'hypnotic imagery fragmentary tale explore connections place personal identity',
#  'like kissing jessica stein amy orgasm key strength willingness explore principal characters honesty insight humor',
#  'cheery earth film warm cozy feeling relaxing around old friends',
#  'one best movies ever made life moviemaking',
#  'normal screen process bromides would barely enough sustain interstitial program discovery channel imax clich disappear vertiginous perspectives opened photography',
#  'fleet footed pleasingly upbeat family diversion',
#  'irwin earnest hard resist pleas spare wildlife respect environs far worse messages teach young audience probably perfectly happy sloppy slapstick comedy',
#  'mostly well constructed fluff seems intended',
#  'gentle affecting melodrama luvvies raptures far slight introspective appeal anything wider niche audience',
#  'stirring funny finally transporting imagining beauty beast horror films',
#  'film epic scale intimate feeling saga ups downs friendships',
#  'good documentary make interesting subject thought would leave cold case point doug pray scratch',
#  'fairy tale formula serves paper skeleton good acting dialogue comedy direction especially charm',
#  'get past taboo subject matter well worth time',
#  'film quiet power',
#  'moments hilarity',
#  'neither parker donovan typical romantic lead bring fresh quirky charm formula',
#  'captivatingly quirky hybrid character portrait romantic comedy beat clock thriller',
#  'thriller made completist checklist rather cultist passion',
#  'endearingly offbeat romantic comedy great meet cute gimmick',
#  'experience engrossing like buried new environment',
#  'engrossing portrait man whose engaging manner flamboyant style made truly larger life character',
#  'intense effective film loneliness chilly anonymity environments many us spend much time',
#  'sensitively examines general issues race justice among poor specifically raises serious questions death penalty asks good execution mentally challenged woman could possibly',
#  'city reminds us realistically nuanced robert de niro performance lucratively engaged shameless self caricature analyze analyze promised threatened later year',
#  'many ways reminiscent unforgiven also utilized scintillating force actors draw menace sparse dialogue',
#  'lot tooth roger dodger nice casual intelligence permeates script',
#  'moving tale love destruction unexpected places unexamined lives',
#  'could daytime soap opera actually compelling look young woman tragic odyssey',
#  'fine rousing g rated family film aimed mainly little kids plenty entertainment value keep grown ups squirming seats',
#  'digital effects reminded terry gilliam rudimentary old monty python cartoons would cut figures drawings photographs paste together',
#  'genius work speaks volumes offering hallucinatory dreamscape frustrates captivates',
#  'plot weaves us complex web',
#  'surreal dream detailed photograph visually dexterous times imaginatively overwhelming',
#  'ridiculous course also refreshing disarming outright enjoyable despite ridiculousness',
#  'trades run mill revulsion extreme unease',
#  'remarkable minute meditation nature revolution',
#  'era big stars high production values standard procedure narc strikes defiantly retro chord outpaces contemporaries daring verve',
#  'indelible epic american story two families one black one white facing change inner outer lives',
#  'solid cast assured direction complete lack modern day irony',
#  'year greatest adventure jackson limited enthusiastic adaptation made literature literal without killing soul feat thinking person bound appreciate',
#  'edifying glimpse wit revolutionary spirit performers era',
#  'nothing short wonderful ten year old female protagonist steadfast refusal set dualistic battle good evil',
#  'throwing caution wind invitation hedonist us nair constructed motion picture way even cynical curmudgeon find smiling one time another',
#  'n directed stage version elling gets fine performances two leads originated characters stage',
#  'films made little moments changing lanes tries reach effort gratefully received',
#  'b movie sit enjoy certain level forget',
#  'slightly flawed fairly unbelievable finale everything else top shelf',
#  'sensitive smart savvy compelling coming age drama delves passive aggressive psychology co dependence struggle self esteem',
#  'alain choquart camera barely stops moving portraying turmoil time giving conduct perpetual sense urgency film takes nearly three hours unspool funny irritating',
#  'philosophical musings dialogue jar tawdry soap opera antics film action way surprisingly enjoyable',
#  'like english patient unbearable lightness hours one reputedly unfilmable novels bucked odds emerge exquisite motion picture right',
#  'highly irritating first mr koury passive technique eventually begins yield interesting results',
#  'reveals important special talents put service others also shows deeply felt emotions draw people together across walls might otherwise separate',
#  'movie ultimately relies bit heavily grandstanding emotional rocky like moments warm charming package feel happy argue much',
#  'insanely hilarious laughed hard years',
#  'gags often stitch',
#  'unbelievably fun film leading man away perfection',
#  'complain time seeing ideas repeated films bourne identity proves fresh take always possible',
#  'confirms fincher status film maker artfully bends technical know service psychological insight',
#  'combines comically dismal social realism farcically bawdy fantasy redemption regeneration',
#  'film lacks general focus makes compassion corcuera manages find seeds hope form collective action',
#  'piercingly affecting clearly manipulative film emerges powerful rather cloying',
#  'asks nothing audience sit back enjoy couple great actors hamming',
#  'flaws also stretches impact moments awe wrapped characters make choices',
#  'one best films ever seen constantly pulling rug underneath us seeing things new sides plunging deeper getting intense',
#  'thankfully film skirts rapidly deteriorating line fantasy reality takes tongue cheek attitude even pushes croc hunter agenda',
#  'film painfully authentic performances young players utterly convincing',
#  'call full monty ice underdog sports team formula redux',
#  'smart movie knows classical music knows freud knows sade',
#  'good script good dialogue funny even adults characters interesting often creatively constructed figure backstory film play equally well standard giant screens',
#  'sillier cuter shorter first best remember still good time cinema',
#  'hard endearing caring warm bring tissues',
#  'gay straight kissing jessica stein one greatest date movies years',
#  'beguiling slow moving parable collision past present remote seacoast iran',
#  'charming funny ultimately silly movie',
#  'admit xxx deep petri dish well characterized telephone book still say guilty pleasure',
#  'entertaining colorful action filled crime story intimate heart',
#  'pete screenplay manages find real natural even flowing tone movies able accomplish',
#  'though lan yu lacks sense dramatic urgency film makes pleasing verisimilitude',
#  'despite overwrought ending film works well performances',
#  'well paced satisfying little drama deserved better direct video release',
#  'odd distant portuguese import less borrows bad lieutenant les vampires comes kind art house gay porn film',
#  'still adam sandler little nicky many us good enough',
#  'labute careful handling makes material seem genuine rather pandering',
#  'shainberg weaves carefully balanced scenario controlled neither character weirdly sympathetic manages tender darkly comic',
#  'tender touching drama based true story troubled african american quest come terms origins reveals yearning hearts acceptance within family circle',
#  'good entirely fresh look war',
#  'chicago offers much colorful eye candy including spectacle gere dancing shoes hoofing crooning best',
#  'enjoyable film family amusing cute adults kids',
#  'one outstanding thrillers recent years',
#  'animation increasingly emphasizes computer cool film takes stand favor tradition warmth',
#  'lot smarter average bond',
#  'beautifully crafted brutally honest promises offers unexpected window complexities middle east struggle humanity people',
#  'conversations may bit enigmatic overly ambitious fully successful sprecher screenwriting partner sister karen sprecher seem ever run ideas',
#  'director peter kosminsky gives women forum demonstrate acting chops take full advantage',
#  'reno take credit movie success one cool actors never seems aware coolness',
#  'really pan american movie moments genuine insight urban heart',
#  'daring beautifully made',
#  'aniston last decisively broken friends image independent film satiric fire emotional turmoil',
#  'deeper direct connection women one spans time reveals meaning bet makes rather convoluted journey worth taking',
#  'spielberg picture smarter subtler total recall blade runner although plot may prove convoluted fun seeking summer audiences',
#  'one genuinely sweet films come along quite time',
#  'brian de palma utterly mad cinema mad set piece mad style mad beautiful madness',
#  'wild thornberrys movie sibling rivalry general family chaos anyone relate',
#  'nine queens frighteningly capable debut genre piece also snapshot dangerous political situation verge coming head',
#  'stands one year intriguing movie experiences letting imagery speak forces ponder anew movie',
#  'generation x artifact capturing brief era insanity sports arena surely cannot last',
#  'sexy surprising romance idemoto kim make gorgeous pair scenes brim sexual possibility emotional danger',
#  'years russian history culture compressed evanescent seamless sumptuous stream consciousness',
#  'though means best work laissez passer distinguished distinctive effort bona fide master fascinating film replete rewards willing make effort reap',
#  'beautifully shot delicately scored powered set heartfelt performances lyrical endeavour',
#  'symbols float like butterflies spinning styx sting like bees wanted',
#  'somewhat blurred kinnear performance razor sharp',
#  'love cinema paradiso find new scenes interesting find movie improved',
#  'recoing fantastic performance exactly reveal makes vincent tick perhaps definitive explanation would felt like cheat',
#  'k stays afloat decent drama action flick',
#  'unflappable air decadent urbanity everett remains perfect wildean actor relaxed firth displays impeccable comic skill',
#  'adapted kevin molony simon leys novel death napoleon directed alan taylor napoleon journey interesting parisian rebirth stillborn',
#  'writer director joe carnahan grimy crime drama manual precinct cliches moves fast enough cover clunky dialogue lapses logic',
#  'fire torpedo clancy holes scripters deserve oscars nerve raked acting crackle lines impressive stagings hardware make robust scary entertainment',
#  'overall good trying',
#  'gleefully grungy hilariously wicked black comedy',
#  'thing guys like evans never quite sure self promotion ends truth begins watch movie interested care',
#  'respectful film byatt fans could hope though lovers book may wonder necessary',
#  'mais um momento inspirado de david fincher',
#  'lilo stitch edgy piece disney animation hit silver screen first film use watercolor background since dumbo certainly ranks original years',
#  'perfectly respectable perfectly inoffensive easily forgettable film',
#  'films captured chaos urban conflagration fury audience members leave feeling shaken nesbitt cooper looks bullets stop flying',
#  'represents better average movie making demand dumb distracted audience',
#  'zhang done amazing job getting realistic performances mainly nonprofessional cast',
#  'stunning film one kind tour de force',
#  'though ways similar catherine breillat fat girl rain far superior film',
#  'uncluttered resonant gem relays universal points without lectures confrontations',
#  'twohy good yarn spinner ultimately story compels',
#  'scotland looks wonderful fans often funny fanatics showdown sure beats bad day golf',
#  'undercover brother definitely one masses also full sharp smart satire',
#  'mcfarlane animation lifts film firmly level coming age films also jarring hard get back boys story',
#  'dominant christine sylvie testud icily brilliant',
#  'plummer steals show without resorting camp nicholas wounded wounding uncle ralph great performance reminder dickens grandeur',
#  'slam bang superheroics kinetic enough engross even antsy youngsters',
#  'life size reenactment jack chick cartoon tracts always ended hippie getting tossed lake fire',
#  'plays like high end john hughes comedy kind elder bueller time',
#  'maelstrom deliberately unsteady mixture stylistic elements',
#  'unusual thoughtful bio drama rich subject fantastic moments scenes',
#  'one funny popcorn flick',
#  'bourne identity half entertaining director doug liman colleagues managed pack enough action satisfy boom bam crowd without huge sacrifice character mood',
#  'must see sides political spectrum',
#  'clear picture killed bob crane glimpse life',
#  'film messages tolerance diversity particularly original one help drawn sympathetic characters',
#  'might easier watch video home stop die hard french film connoisseurs going enjoying big screen experience',
#  'great escapist fun recreates place time never happen',
#  'sports movie action exciting field story care',
#  'never dull always looks good',
#  'series tales told intricate preciseness best short story writing',
#  'lives worth watching paths worth following',
#  'watching film one left inescapable conclusion hitchens obsession kissinger bottom sophisticated flower child desire purge world tooth claw human power',
#  'jaw droppingly beautiful work upends nearly every clich japanese animation delivering satisfactory amount carnage',
#  'wild ride movie keeps throwing fastballs',
#  'spectacular every sense word even know orc uruk hai',
#  'passion melodrama sorrow laugther tears cascade screen effortlessly',
#  'hands year thought provoking film pays price intricate intellectual gamesmanship',
#  'overly melodramatic somewhat insightful french coming age film',
#  'george clooney first directorial effort presents utterly ridiculous shaggy dog story one creative energetic original comedies hit screen years',
#  'real winner smart funny subtle resonant',
#  'emerge dazed confused whether seen pornography documentary',
#  'si bien logra desarrollarse como un gran drama tampoco es tan superficial como muchas cintas que pecan de pretenciosas que resultan totalmente banales',
#  'taut psychological thriller waste moment two hour running time',
#  'pain loneliness insecurity screenwriting process vividly painfully brought slovenly life self deprecating biting witty feature written charlie kaufman twin brother donald directed spike jonze',
#  'wise powerful tale race culture forcefully told superb performances throughout',
#  'antonia assimilated newfangled community film settles becomes compulsively watchable guilty pleasure daytime drama sort fashion',
#  'beautifully choreographed kitchen ballet simple absorbing',
#  'driven fantastic dual performance ian holm film funny insightfully human delightful lark history buffs',
#  'compelling allegory last days germany democratic weimar republic',
#  'though mama takes bit long find rhythm third act plot development somewhat melodramatic ribald humor touching nostalgia sure please anyone search jules jim new millennium',
#  'like movie children song includes line stepdad mean adjusting',
#  'drama played aching beauty truth brings tears eyes',
#  'rare find film dazzles eye challenges brain satisfies lust fast paced action minority report delivers whole lot',
#  'yakusho always wonderful long faced sad sack chemistry shimizu believable',
#  'one pleasures walter documentary parade veteran painters confounded dealers miscellaneous bohos expound upon subject mysterious personality without ever explaining',
#  'sentimental cliches mar otherwise excellent film powerful performance mel gibson brutal minute battle sequence everything issue dog tag',
#  'makes compelling provocative prescient viewing',
#  'perceptive good natured movie',
#  'even pronounce gyro correctly appreciate much vardalos humor transcends ethnic boundaries',
#  'irresistible combination rousing good story set truly grand scale',
#  'neither quite comedy romance impish divertissement themes interest attal gainsbourg live together film lot charm',
#  'nicely combines enigmatic features memento hallucinatory drug culture requiem dream',
#  'nicely serves examination society transition',
#  'soderbergh skims fat film left rich stew longing',
#  'serious sense purpose finds way lay bare tragedies setting good deal warmth humor',
#  'always something likable marquis de sade',
#  'one liners snappy situations volatile comic opportunities richly rewarded',
#  'anyone passion cinema indeed sex see soon possible',
#  'even tedious scenes russian ark mesmerizing',
#  'jackson tries keep plates spinning best bouncing back forth help become bit tedious even breathtaking landscapes villainous varmints distract ricocheting',
#  'brian tufano handsome widescreen photography paul grabowsky excellent music turn fairly parochial melodrama something really rather special',
#  'charming romantic comedy far lightest dogme film among enjoyable',
#  'oddity sure one might wind remembering degree affection rather revulsion',
#  'first attempt film noir spielberg presents fascinating flawed look near future',
#  'brings together biggest names japanese anime impressive results',
#  'plot amusingly contrived outlandish coincidences one could ever mistake anything resembling reality',
#  'superbly photographed staged mendes series riveting set pieces likes mainstream audiences rarely seen',
#  'gentle blend present day testimonials surviving footage burstein family performing historical archives telling stills',
#  'film becomes overwhelming pleasure find rooting gai character avoid fate befallen every carmen',
#  'vitality actors keeps intensity film high even strafings blend together',
#  'reminder used make movies also sometimes still made',
#  'judge one soon dark gritty story takes totally unexpected directions keeps going',
#  'hard look one man occupational angst subsequent reinvention terrifying study bourgeois desperation worthy claude chabrol',
#  'dark quirky road movie constantly defies expectation',
#  'rollicking adventure mateys regardless ages',
#  'decades marveled disney rendering water snow flames shadows hand drawn animated world prepare marvel',
#  'effectively creepy fear inducing fear reducing film japanese director hideo nakata takes superstitious curse chain letters actually applies',
#  'gosling provides amazing performance dwarfs everything else film',
#  'compulsively watchable matter degraded things get',
#  'huppert gives erika persona intriguing find staring hypnotically trying understand wondering crack',
#  'beautiful paean time long past',
#  'refreshing change self interest paranoia shape american representations castro',
#  'liotta put pounds role completely transformed smooth goodfellas image',
#  'blade ii merges bits pieces fighting games wire fu horror movies mystery james bond wrestling sci fi anime one big bloody stew',
#  'happy listening movies watching slow parade human frailty fascinates right film',
#  'poetic heartbreaking',
#  'hugh grant good line charm never charming boy',
#  'powers team fashioned comedy laughs many question time mold gold',
#  'like brosnan performance evelyn comes heart',
#  'quiet family drama little bit romance dose darkness',
#  'critics need good laugh extreme tv rendition notorious mtv show delivers outrageous sickening sidesplitting goods steaming visceral heaps',
#  'triumph art direction narrative art direction',
#  'intelligently made beautifully edited picture least spark life say plenty movies flow hollywood pipeline without hitch',
#  'quite equal woo best earlier work easily finest american film comes close recapturing brilliance hong kong films',
#  'refreshingly realistic affectation free coming age tale',
#  'film vision sport secular religion bit cloying line family community heartening way season marks new start',
#  'lively account seinfeld deadpan',
#  'dutifully pulling heartstrings directors dean deblois chris sanders valiantly keep punching mix',
#  'inuit masterpiece give goosebumps uncanny tale love communal discord justice unfolds',
#  'enjoyably fast moving hard hitting documentary',
#  'son bride humour born engaging storyline also embarrassed make reach tissues movie cherished',
#  'film one year best',
# ...
#  'much storytelling moves away solondz social critique casting audience intellectual lector contemplation auteur professional injuries',
#  'consumers lo mein general tso chicken barely give thought folks prepare deliver hopefully film attach human face little steaming cartons',
#  'really need minute film tell us exactly romantic relationship year old boy year old woman work',
#  'invitingly upbeat overture pathos filled ultimately life affirming finale martin masterfully conducted work',
#  'earns laughs stock redneck types many many moments recognize even without elizabethan prose play behind thing',
#  'hint awkward hitchcockian theme tact harmon daunting narrative promotes reasonable landscape conflict pathos support scattershot terrorizing tone',
#  'found liking film though case one man treasure could prove another man garbage',
#  'american european cinema amassed vast holocaust literature impossible think film challenging depressing grey zone',
#  'allen underestimated charm delivers goodies lumps coal',
#  'captivating cross cultural comedy manners',
#  'aside minor tinkering movie probably loved except looks even better',
#  'passions aroused discord old new cultures set strange stark beauty mideast desert lovingly perceptively filmed almost taste desiccated air',
#  'complex politically charged tapestry contemporary chinese life exciting new filmmaker brought screen like nothing westerners seen',
#  'poetry motion captured film bit repetitive overall entertaining informative documentary',
#  'swimming young woman face casting actress whose face projects woman doubts yearnings succeeds',
#  'bundy michael reilly burke octopus river fear right amount charisma menace',
#  'captivates shows excess business pleasure allowing us find small human moments leaving grand whimper',
#  'zany exuberantly irreverent animated space adventure',
#  'turns cut norm thanks clever writing sprightly acting',
#  'exactly gourmet meal fare fair even coming drive thru',
#  'much better documentary revealing emotional surprising pedestrian english title would believe',
#  'plotless shapeless yet must admitted entirely humorless indeed outrageous bits achieve shock laughter intensity almost dadaist proportions',
#  'although frailty fits classic genre script execution remarkably original work',
#  'es divertida visualmente espectacular muy entretenida simple sencillamente te sorprender',
#  'radio soundtrack game cast tierney inimitable walken especially keep unusual comedy choking conceit',
#  'large cast representing broad cross section tavernier film bounds along rat tat energy girl friday maintaining light touch tackling serious themes',
#  'cletis playful highly studied dependent success patient viewer',
#  'believe much laugh audacity casting sheer insanity',
#  'sometimes like go movies fun wasabi good place start',
#  'visual flourishes little obvious restrained subtle storytelling fine performances make delicate coming age tale treat',
#  'mr spielberg company want enjoy without feeling conned succeed merrily noble endeavor',
#  'khouri manages terrific flair keep extremes screwball farce blood curdling family intensity one continuum',
#  'watchable movie quite memorable experience might',
#  'rare lightly entertaining look behind curtain separates comics people laughing crowd',
#  'superior horror flick',
#  'guiltless film nice evening',
#  'combines improbable melodrama gored bullfighters comatose ballerinas subtly kinky bedside vigils sensational denouements yet end undeniably touched',
#  'never seen heard anything quite like film recommend originality alone',
#  'sophomore slump director sam mendes segues oscar winner oscar winning potential smooth sleight hand',
#  'one original american productions year find remembering refreshing visit sunshine state',
#  'dogtown z boys exposes roots skateboarding boom would become punk kids revolution',
#  'spielberg managed marry science fiction film noir action flicks philosophical inquiry',
#  'really counts bloody sunday connects visceral level transcends language',
#  'know never listen marvin gaye supremes way',
#  'uniquely sensual metaphorical dramatization sexual obsession spends bit much time fairly ludicrous plot',
#  'quietly introspective portrait self esteem employment shame losing job',
#  'one best examples treat subject fully aware examined much like photo know taken',
#  'film deliberately lacks irony genuine dramatic impact plays like powerful drama somehow never seen',
#  'summer overrun movies dominated cgi aliens super heroes revigorates mind see feature concentrates people project script characters hold sway',
#  'saddled unwieldy cast characters angles payoff powerful revelatory',
#  'way coppola professes love movies colorful pop junk classics unequivocally qualify art giddily entertaining',
#  'succeeds well made evocation subculture',
#  'enjoyably dumb sweet intermittently hilarious taste quirky steal glimpse',
#  'methodical measured gently tedious comedy secret ballot purposefully reductive movie may successful lodging brain',
#  'writer director alexander payne election co writer jim taylor brilliantly employ quirky fearless ability look american angst eye end laughing',
#  'often hilarious',
#  'bracing unblinking work serves painful elegy sobering cautionary tale',
#  'thoughtful surprisingly affecting portrait screwed man dared mess powerful people seen eyes idealistic kid chooses champion ultimately losing cause',
#  'ambitious unsettling psychodrama takes full chilling advantage rough around edges low budget constraints',
#  'cat meow marks return form director peter bogdanovich',
#  'like old myths wonder tales spun afresh',
#  'perfect show respect one underrated professionals deserve rarely receive',
#  'seriocomic debut extravagant promise georgian israeli director dover kosashvili',
#  'best garcia perfectly portrays desperation insecure man',
#  'barry convinces us dangerous secretly unhinged guy could easily killed president made feel powerful',
#  'denver get first last look one triumphant performances vanessa redgrave career deserves seen everywhere',
#  'vastness implied metropolis breathtaking',
#  'lovely eerie film casts odd rapt spell',
#  'vividly demonstrates director hollywood blockbusters patriot games still turn small personal film emotional wallop',
#  'tale passionate tumultuous affair musset unfolds sand masculine persona love life beauty takes form',
#  'fine focused piece work reopens interesting controversy never succumbs sensationalism',
#  'psychoanalytical provocatively also refreshingly literary',
#  'compelling journey best friend remembers finest specials',
#  'tricky satisfying david mamet airless cinematic shell games',
#  'retooled genre piece tale guy gun amiably idiosyncratic work',
#  'lauren ambrose comes alive attention two strangers town honest performances realistic interaction characters coming age story twist',
#  'stock silver bullets director neil marshall intense freight train film',
#  'macdowell gives give solid anguished performance eclipses nearly everything else ever done',
#  'grimly competent stolid earnest military courtroom drama',
#  'biggest problem movie nearly long enough',
#  'ayurveda help us return sane regimen eating sleeping stress reducing contemplation clearly good thing',
#  'lot credit film winning tone must go grant lost bit dry humor first made audiences sides atlantic love',
#  'extraordinary film least japanese yet feels universal',
#  'work transcends boy meets girl posturing typical love stories',
#  'astonishingly skillful moving could become historically significant work well masterfully made one',
#  'much smarter attentive first sets',
#  'maybe past year seen release worst film comedies decades honestly analyze really bad',
#  'one rare docs paints grand picture era makes journey feel like party',
#  'ever possible say williams truly inhabited character',
#  'right brilliant piece filmmaking funny sometimes hilarious comedy deft sense humor playful spirit game cast',
#  'much tongue cheek film doubt filmmaker fun',
#  'particularly well made since found howling cringing say film works',
#  'energetic violent movie momentum never lets',
#  'watching film feel mainly suspense excitement dominant feeling something like nostalgia',
#  'hoffman notches nuances pain smart edgy voice waddling profile emphasized accent humor wilson plight saves pathos drippiness',
#  'averting eyes solondz forces us consider unthinkable unacceptable unmentionable',
#  'sometimes need comforting fantasies mental illness also need movies like tim mccann revolution',
#  'although german cooking come readily mind considering world best cuisine mostly martha could make deutchland popular destination hungry tourists',
#  'brutally honest told humor poignancy makes message resonate',
#  'life rez picnic picture shows',
#  'reminiscent alfred hitchcock thrillers scary parts signs occur waiting things happen',
#  'bilingual charmer like woman inspired',
#  'life affirming heartbreaking sweet without decay factor funny sad',
#  'charms lead performances allow us forget film problems',
#  'brave attempt tap heartbeat world salute universal language rhythm zippy sampling sounds',
#  'one rare films seems though written one somehow manages convince almost everyone put screen',
#  'features one affecting depictions love affair ever committed film',
#  'director peter jackson crew steeped majesty tolkien writing every frame produces new joys whether fan books',
#  'cuts right b giving big middle fingered shut talk nothing two guys beating hell outta one another',
#  'allen se atreve atacar atacarse nos ofrece gags que van de la sonrisa la risa de larga duraci n',
#  'gangs despite gravity subject matter often fun watch good spaghetti western',
#  'best early plays culture clashes brothers',
#  'subtitled costume drama set remote african empire cell phones guns internal combustion engine politics thump timely tomorrow',
#  'result something quite fresh delightful',
#  'dares little different shading makes worthwhile',
#  'hoffman performance authentic core',
#  'poignant familiar story young person suspended two cultures',
#  'white oleander may leave rolling eyes dark mean like looking',
#  'ice cube holds film together engaging warm performance',
#  'film may hit hard better drug related pictures still manages get punches',
#  'digital video documentary stand comedians great glimpse different world',
#  'sensual funny end touching',
#  'much fatale outside stylish surprises ok',
#  'gooding energetic frontman hard resist enthusiasm even filmmakers come nothing original way slapstick sequences',
#  'deliberately skillfully uses ambiguity suggest possibilities imbue theme added depth resonance',
#  'storylines woven together skilfully magnificent swooping aerial shots breathtaking overall experience awesome',
#  'miniscule little bleep film radar one many people check',
#  'gives devastating testimony people capacity evil heroic capacity good',
#  'whole cast looks much fun slapstick antics silly street patois tossing around obscure expressions like bellini mullinski compact minutes breezes',
#  'solidly seaworthy chiller',
#  'helps lil bow wow tones pint sized gangsta act play someone resembles real kid',
#  'goldmember funny enough justify embarrassment bringing barf bag moviehouse',
#  'fascinating unnerving examination delusions one unstable man',
#  'broad cartoonish screenplay accuracy observation work director frank novak keeps film grounded undeniable social realism',
#  'allows us hope nolan poised embark major career commercial yet inventive filmmaker',
#  'quite comedy film tackles relatively serious subject open mind considerable good cheer never less engaging',
#  'like sucker good old fashion romance someone shamelessly loves eat mostly martha offers perfect ingredients satisfy appetite',
#  'like great documentaries goes one truth ford administration complicity tearing orphans mothers stumbles upon others even compelling',
#  'map inner rhythms love jealousy sacrifice drawn master steady stroke',
#  'collateral damage finally delivers goods schwarzenegger fans',
#  'run walk see barbed bracing comedy big screen',
#  'emperor club ruthless placid way finds one conservative hidebound movie making traditions gives new texture new relevance new reality',
#  'makes film special refreshingly unhibited enthusiasm people spite clearly evident poverty hardship bring music',
#  'biopic crane life classic tradition evolves become us era video',
#  'manages fall closer quality silence abysmal hannibal',
#  'fun wispy wise surprisingly inoffensive film teen love stepmom',
#  'blushing gushing imamura squirts screen warm water red bridge',
#  'princess sorvino glides gracefully male persona female without missing beat ben kingsley truly funny playing kind ghandi gone bad',
#  'marvelously entertaining deliriously joyous documentary',
#  'always fascinating watch marker essayist work',
#  'peppering urban study references norwegian folktales villeneuve creates maelstrom world bizarre credible real turns magical',
#  'good performances realistic non exploitive approach make paid full worth seeing',
#  'tsai convincingly paints specifically urban sense disassociation',
#  'human resources good straightforward tale time better haunting like poem',
#  'better predecessor may rate magical fun family fare recent holiday season',
#  'movie one best examples artful large format filmmaking likely see anytime soon',
#  'whether enlightened derrida lectures self derrida undeniably fascinating playful fellow',
#  'storytelling value cannot denied even solondz thirst controversy sketchy characters immature provocations fully succeed cheapening',
#  'terrific insider look star making machinery tinseltown',
#  'truly awful heartbreaking subject matter one whose lessons well worth revisiting many times possible',
#  'intimate good humored ethnic comedy like numerous others cuts deeper expected',
#  'film powerful accessible funny miss messages entertained well',
#  'alternately fascinating frustrating documentary',
#  'compelling spanish film withering effects jealousy life young monarch whose sexual passion husband becomes obsession',
#  'smith finds amusing juxtapositions justify exercise',
#  'psychologically rich suspenseful moral thriller stellar performance al pacino',
#  'piccoli gives superb performance full deep feeling',
#  'tender yet lacerating darkly funny fable',
#  'raw action packed experience ringside seat tough man contest',
#  'elling portrayed quiet fastidiousness per christian ellefsen truly singular character one whose frailties slightly magnified versions ones vex nearly everyone',
#  'enough finely tuned acting compensate movie failings',
#  'people want ol ball chain want ball chain',
#  'fast paced suspenseful argentinian thriller shadow side play',
#  'filmmaking may bit disjointed subject matter fascinating care',
#  'ichi killer takashi miike japan wildest filmmaker gives us crime fighter carrying emotional baggage batman',
#  'intriguing downright intoxicating',
#  'nair use monsoon wedding lament loss culture instead sees chance revitalize always remarkable clung traditions',
#  'response new sequel analyze may hinge thought first film',
#  'may brainer least funny brainer',
#  'although jackson doubtless reserving darkest hours return king long greater sense urgency two towers',
#  'definitely step right direction',
#  'wise elegiac',
#  'mostly works universal themes earnest performances excellent use music india popular gulzar jagjit singh',
#  'despite flaws crazy hell marks encouraging new direction la salle',
#  'best enjoyed work fiction inspired real life events seeking definitive account eisenstein life would better elsewhere',
#  'admirable reconstruction terrible events fitting memorial dead day thousands thereafter',
#  'storytelling may ordinary cast one star reunions fans gosford park come assume another day brit cinema',
#  'almost spectacular coastal setting distracts slightly eccentric good naturedly aimless story',
#  'wonder wonders teen movie humanistic message',
#  ...]
